# %% [markdown]
# # **1. 공공데이터**
# 공공데이터(data.go.kr)는 대한민국 정부에서 운영하는 공공데이터 포털로, 공공기관이 보유한 다양한 데이터를 국민과 기업, 개발자 등에게 개방하여 활용할 수 있도록 제공하는 플랫폼입니다. 데이터를 파일 형식(Excel, CSV 등)으로 다운로드하거나, API 형태로 실시간 연동하여 사용할 수 있습니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
shop = pd.read_csv('/content/drive/MyDrive/AI활용 소프트웨어 개발/11. 데이터 분석/data/소상공인시장진흥공단_상가(상권)정보_서울_202503.csv', low_memory=False)
shop
# Out:
#                       상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220800000033    부동산임대김은숙  NaN        I2       음식      I212
# 1       MA010120220800000036   한국황토건축연구소  NaN        L1      부동산      L102
# 2       MA010120220800000077  소망공인중개사사무소  NaN        L1      부동산      L102
# 3       MA010120220800000084         고향집  NaN        I2       음식      I201
# 4       MA010120220800000090        보석나라  NaN        G2       소매      G217
# ...                      ...         ...  ...       ...      ...       ...
# 540512  MA0101202502A0113097      동양에이전시  NaN        M1    과학·기술      M105
# 540513  MA0101202502A0113099        서관면옥  NaN        M1    과학·기술      M107
# 540514  MA0101202502A0113654         아리가  NaN        I2       음식      I203
# 540515  MA0101202502A0113657         백압관  NaN        I2       음식      I201
# 540516  MA0101202502A0114234          술각  NaN        I2       음식      I211
#
#          상권업종중분류명 상권업종소분류코드    상권업종소분류명 표준산업분류코드  ...  \
# 0           비알코올     I21201          카페   I56229  ...
# 1         부동산 서비스    L10203  부동산 중개/대리업   L68221  ...
# 2         부동산 서비스    L10203  부동산 중개/대리업   L68221  ...
# 3              한식    I20101      백반/한정식   I56111  ...
# 4       시계·귀금속 소매    G21701  시계/귀금속 소매업   G47830  ...
# ...           ...       ...         ...      ...  ...
# 540512         광고    M10504  광고물 설계/제작업   M71393  ...
# 540513  본사·경영 컨설팅    M10703     경영 컨설팅업   M71531  ...
# 540514         일식    I20301     일식 회/초밥   I56122  ...
# 540515         한식    I20101      백반/한정식   I56111  ...
# 540516         주점    I21103      생맥주 전문   I56213  ...
#
#                            건물관리번호     건물명                    도로명주소   구우편번호  \
# 0       1111014000100280021026727     NaN      서울특별시 종로구 삼청로 122-1  110230
# 1       1165010800113080025020133  강남오피스텔     서울특별시 서초구 서초대로73길 40  137856
# 2       1120012200100040011000899     NaN     서울특별시 성동구 용답중앙15길 18  133847
# 3       1111015400100800000000001     NaN      서울특별시 종로구 돈화문로4길 30  110430
# 4       1153010700103590008007958     NaN       서울특별시 구로구 개봉로3길 23  152815
# ...                           ...     ...                      ...     ...
# 540512  1144012000103470021024741    기린빌딩      서울특별시 마포구 어울마당로 130  121837
# 540513  1114012400100540000023233  신세계백화점          서울특별시 중구 퇴계로 77  100011
# 540514  1165010800113600031023092    정진빌딩  서울특별시 서초구 강남대로41길 15-19  137863
# 540515  1168010400100530003017865     NaN      서울특별시 강남구 학동로97길 74  135952
# 540516  1123010800100600051010343     NaN     서울특별시 동대문구 경희대로1길 13  130872
#
#        신우편번호  동정보  층정보  호정보          경도         위도
# 0       3053  NaN  NaN  NaN  126.981840  37.586250
# 1       6612  NaN   11  NaN  127.024563  37.500924
# 2       4805  NaN    1  NaN  127.054262  37.564786
# 3       3193  NaN  NaN  NaN  126.993820  37.570025
# 4       8353  NaN    1  NaN  126.855046  37.486242
# ...      ...  ...  ...  ...         ...        ...
# 540512  4053  NaN    3  NaN  126.924524  37.555810
# 540513  4530  NaN   14  NaN  126.980771  37.560355
# 540514  6730  NaN    2  NaN  127.032179  37.486407
# 540515  6071  NaN    1  NaN  127.053113  37.524197
# 540516  2454  NaN    1  NaN  127.051360  37.591691
#
# [540517 rows x 39 columns]

# %%
pd.set_option('display.max_columns', 40)
shop
# Out:
#                       상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220800000033    부동산임대김은숙  NaN        I2       음식      I212
# 1       MA010120220800000036   한국황토건축연구소  NaN        L1      부동산      L102
# 2       MA010120220800000077  소망공인중개사사무소  NaN        L1      부동산      L102
# 3       MA010120220800000084         고향집  NaN        I2       음식      I201
# 4       MA010120220800000090        보석나라  NaN        G2       소매      G217
# ...                      ...         ...  ...       ...      ...       ...
# 540512  MA0101202502A0113097      동양에이전시  NaN        M1    과학·기술      M105
# 540513  MA0101202502A0113099        서관면옥  NaN        M1    과학·기술      M107
# 540514  MA0101202502A0113654         아리가  NaN        I2       음식      I203
# 540515  MA0101202502A0113657         백압관  NaN        I2       음식      I201
# 540516  MA0101202502A0114234          술각  NaN        I2       음식      I211
#
#          상권업종중분류명 상권업종소분류코드    상권업종소분류명 표준산업분류코드               표준산업분류명  시도코드  \
# 0           비알코올     I21201          카페   I56229          기타 비알코올 음료점업    11
# 1         부동산 서비스    L10203  부동산 중개/대리업   L68221          부동산 중개 및 대리업    11
# 2         부동산 서비스    L10203  부동산 중개/대리업   L68221          부동산 중개 및 대리업    11
# 3              한식    I20101      백반/한정식   I56111            한식 일반 음식점업    11
# 4       시계·귀금속 소매    G21701  시계/귀금속 소매업   G47830          시계 및 귀금속 소매업    11
# ...           ...       ...         ...      ...                   ...   ...
# 540512         광고    M10504  광고물 설계/제작업   M71393  광고물 문안; 도안; 설계 등 작성업    11
# 540513  본사·경영 컨설팅    M10703     경영 컨설팅업   M71531               경영 컨설팅업    11
# 540514         일식    I20301     일식 회/초밥   I56122               일식 음식점업    11
# 540515         한식    I20101      백반/한정식   I56111            한식 일반 음식점업    11
# 540516         주점    I21103      생맥주 전문   I56213               생맥주 전문점    11
#
#           시도명  시군구코드  시군구명     행정동코드         행정동명       법정동코드   법정동명  \
# 0       서울특별시  11110   종로구  11110540          삼청동  1111014000    삼청동
# 1       서울특별시  11650   서초구  11650531         서초4동  1165010800    서초동
# 2       서울특별시  11200   성동구  11200790          용답동  1120012200    용답동
# 3       서울특별시  11110   종로구  11110615  종로1.2.3.4가동  1111015400    장사동
# 4       서울특별시  11530   구로구  11530760         개봉3동  1153010700    개봉동
# ...       ...    ...   ...       ...          ...         ...    ...
# 540512  서울특별시  11440   마포구  11440660          서교동  1144012000    서교동
# 540513  서울특별시  11140    중구  11140540          회현동  1114012400  충무로1가
#
#         신우편번호  동정보  층정보  호정보          경도         위도
# 0        3053  NaN  NaN  NaN  126.981840  37.586250
# 1        6612  NaN   11  NaN  127.024563  37.500924
# 2        4805  NaN    1  NaN  127.054262  37.564786
# 3        3193  NaN  NaN  NaN  126.993820  37.570025
# 4        8353  NaN    1  NaN  126.855046  37.486242
# ...       ...  ...  ...  ...         ...        ...
# 540512   4053  NaN    3  NaN  126.924524  37.555810
# 540513   4530  NaN   14  NaN  126.980771  37.560355
# 540514   6730  NaN    2  NaN  127.032179  37.486407
# 540515   6071  NaN    1  NaN  127.053113  37.524197
# 540516   2454  NaN    1  NaN  127.051360  37.591691
#
# [540517 rows x 39 columns]

# %%
shop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540517 entries, 0 to 540516
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     540517 non-null  object
#  1   상호명        540517 non-null  object
#  2   지점명        48544 non-null   object
#  3   상권업종대분류코드  540517 non-null  object
#  4   상권업종대분류명   540517 non-null  object
#  5   상권업종중분류코드  540517 non-null  object
#  6   상권업종중분류명   540517 non-null  object
#  7   상권업종소분류코드  540517 non-null  object
#  8   상권업종소분류명   540517 non-null  object
#  9   표준산업분류코드   540317 non-null  object
#  10  표준산업분류명    540317 non-null  object
#  11  시도코드       540517 non-null  int64
#  12  시도명        540517 non-null  object
#  13  시군구코드      540517 non-null  int64
#  14  시군구명       540517 non-null  object
#  15  행정동코드      540517 non-null  int64
#  16  행정동명       540517 non-null  object
#  17  법정동코드      540517 non-null  int64
#  18  법정동명       540517 non-null  object
#  19  지번코드       540517 non-null  int64
#  20  대지구분코드     540517 non-null  int64
#  21  대지구분명      540517 non-null  object
#  22  지번본번지      540460 non-null  float64
#  23  지번부번지      448378 non-null  float64
#  24  지번주소       540517 non-null  object
#  25  도로명코드      540517 non-null  int64
#  26  도로명        540517 non-null  object
#  27  건물본번지      540516 non-null  float64
#  28  건물부번지      70031 non-null   float64
#  29  건물관리번호     540516 non-null  object
#  30  건물명        265014 non-null  object
#  31  도로명주소      540517 non-null  object
#  32  구우편번호      540517 non-null  int64
#  33  신우편번호      540517 non-null  int64
#  34  동정보        0 non-null       float64
#  35  층정보        370779 non-null  object
#  36  호정보        0 non-null       float64
#  37  경도         540517 non-null  float64
#  38  위도         540517 non-null  float64
# dtypes: float64(8), int64(9), object(22)
# memory usage: 160.8+ MB

# %%
shop.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
view_columns = ['상호명', '지점명', '상권업종대분류명', '상권업종중분류명',
                '상권업종소분류명', '시도명', '시군구명', '도로명', '도로명주소',
                '경도', '위도']

shop = shop[view_columns]
shop.head()
# Out:
#           상호명  지점명 상권업종대분류명   상권업종중분류명    상권업종소분류명    시도명 시군구명  \
# 0    부동산임대김은숙  NaN       음식      비알코올           카페  서울특별시  종로구
# 1   한국황토건축연구소  NaN      부동산    부동산 서비스  부동산 중개/대리업  서울특별시  서초구
# 2  소망공인중개사사무소  NaN      부동산    부동산 서비스  부동산 중개/대리업  서울특별시  성동구
# 3         고향집  NaN       음식         한식      백반/한정식  서울특별시  종로구
# 4        보석나라  NaN       소매  시계·귀금속 소매  시계/귀금속 소매업  서울특별시  구로구
#
#                  도로명                 도로명주소          경도         위도
# 0      서울특별시 종로구 삼청로   서울특별시 종로구 삼청로 122-1  126.981840  37.586250
# 1  서울특별시 서초구 서초대로73길  서울특별시 서초구 서초대로73길 40  127.024563  37.500924
# 2  서울특별시 성동구 용답중앙15길  서울특별시 성동구 용답중앙15길 18  127.054262  37.564786
# 3   서울특별시 종로구 돈화문로4길   서울특별시 종로구 돈화문로4길 30  126.993820  37.570025
# 4    서울특별시 구로구 개봉로3길    서울특별시 구로구 개봉로3길 23  126.855046  37.486242

# %%
shop.isnull().sum()
# Out:
# 상호명              0
# 지점명         491973
# 상권업종대분류명         0
# 상권업종중분류명         0
# 상권업종소분류명         0
# 시도명              0
# 시군구명             0
# 도로명              0
# 도로명주소            0
# 경도               0
# 위도               0
# dtype: int64

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

plt.rc('font', family='NanumBarunGothic')
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
# 산점도 그리기
plt.figure(figsize=(6, 8))  # 그래프 크기 설정
plt.scatter(shop['경도'], shop['위도'])  # 산점도 그리기
plt.xlabel('경도')  # x축 레이블
plt.ylabel('위도')  # y축 레이블
plt.grid(True)  # 그리드 추가
plt.show()  # 그래프 출력

# %%
len(shop)
# Out:
# 540517

# %%
shop.loc[shop['도로명주소'].str.startswith('서울')]
# Out:
#                상호명  지점명 상권업종대분류명   상권업종중분류명    상권업종소분류명    시도명  시군구명  \
# 0         부동산임대김은숙  NaN       음식      비알코올           카페  서울특별시   종로구
# 1        한국황토건축연구소  NaN      부동산    부동산 서비스  부동산 중개/대리업  서울특별시   서초구
# 2       소망공인중개사사무소  NaN      부동산    부동산 서비스  부동산 중개/대리업  서울특별시   성동구
# 3              고향집  NaN       음식         한식      백반/한정식  서울특별시   종로구
# 4             보석나라  NaN       소매  시계·귀금속 소매  시계/귀금속 소매업  서울특별시   구로구
# ...            ...  ...      ...        ...         ...    ...   ...
# 540512      동양에이전시  NaN    과학·기술         광고  광고물 설계/제작업  서울특별시   마포구
# 540513        서관면옥  NaN    과학·기술  본사·경영 컨설팅     경영 컨설팅업  서울특별시    중구
# 540514         아리가  NaN       음식         일식     일식 회/초밥  서울특별시   서초구
# 540515         백압관  NaN       음식         한식      백반/한정식  서울특별시   강남구
# 540516          술각  NaN       음식         주점      생맥주 전문  서울특별시  동대문구
#
#                       도로명                    도로명주소          경도         위도
# 0           서울특별시 종로구 삼청로      서울특별시 종로구 삼청로 122-1  126.981840  37.586250
# 1       서울특별시 서초구 서초대로73길     서울특별시 서초구 서초대로73길 40  127.024563  37.500924
# 2       서울특별시 성동구 용답중앙15길     서울특별시 성동구 용답중앙15길 18  127.054262  37.564786
# 3        서울특별시 종로구 돈화문로4길      서울특별시 종로구 돈화문로4길 30  126.993820  37.570025
# 4         서울특별시 구로구 개봉로3길       서울특별시 구로구 개봉로3길 23  126.855046  37.486242
# ...                   ...                      ...         ...        ...
# 540512    서울특별시 마포구 어울마당로      서울특별시 마포구 어울마당로 130  126.924524  37.555810
# 540513       서울특별시 중구 퇴계로          서울특별시 중구 퇴계로 77  126.980771  37.560355
# 540514  서울특별시 서초구 강남대로41길  서울특별시 서초구 강남대로41길 15-19  127.032179  37.486407
# 540515   서울특별시 강남구 학동로97길      서울특별시 강남구 학동로97길 74  127.053113  37.524197
# 540516  서울특별시 동대문구 경희대로1길     서울특별시 동대문구 경희대로1길 13  127.051360  37.591691
#
# [540517 rows x 11 columns]

# %%
shop.loc[~shop['도로명주소'].str.startswith('서울')]
# Out:
# Empty DataFrame
# Columns: [상호명, 지점명, 상권업종대분류명, 상권업종중분류명, 상권업종소분류명, 시도명, 시군구명, 도로명, 도로명주소, 경도, 위도]
# Index: []

# %% [markdown]
# # **2. Seaborn**
# [Seaborn](https://seaborn.pydata.org/)은 Python의 데이터 시각화 라이브러리로, Matplotlib 위에 구축되어 데이터를 더 간단하고 쉽게 시각화할 수 있도록 설계되었습니다. 주로 통계적 데이터 시각화에 초점이 맞춰져 있으며, 다양한 차트와 스타일 옵션을 제공합니다.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(14, 10))
sns.scatterplot(data=shop, x='경도', y='위도', hue='시군구명')
# Out:
# <Axes: xlabel='경도', ylabel='위도'>
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
shop.head()
# Out:
#           상호명  지점명 상권업종대분류명   상권업종중분류명    상권업종소분류명    시도명 시군구명  \
# 0    부동산임대김은숙  NaN       음식      비알코올           카페  서울특별시  종로구
# 1   한국황토건축연구소  NaN      부동산    부동산 서비스  부동산 중개/대리업  서울특별시  서초구
# 2  소망공인중개사사무소  NaN      부동산    부동산 서비스  부동산 중개/대리업  서울특별시  성동구
# 3         고향집  NaN       음식         한식      백반/한정식  서울특별시  종로구
# 4        보석나라  NaN       소매  시계·귀금속 소매  시계/귀금속 소매업  서울특별시  구로구
#
#                  도로명                 도로명주소          경도         위도
# 0      서울특별시 종로구 삼청로   서울특별시 종로구 삼청로 122-1  126.981840  37.586250
# 1  서울특별시 서초구 서초대로73길  서울특별시 서초구 서초대로73길 40  127.024563  37.500924
# 2  서울특별시 성동구 용답중앙15길  서울특별시 성동구 용답중앙15길 18  127.054262  37.564786
# 3   서울특별시 종로구 돈화문로4길   서울특별시 종로구 돈화문로4길 30  126.993820  37.570025
# 4    서울특별시 구로구 개봉로3길    서울특별시 구로구 개봉로3길 23  126.855046  37.486242

# %%
shop['상권업종대분류명'].value_counts()
# Out:
# 상권업종대분류명
# 음식         139929
# 소매         113485
# 과학·기술       94149
# 수리·개인       50986
# 교육          44627
# 부동산         25000
# 시설관리·임대     24734
# 예술·스포츠      20416
# 보건의료        18494
# 숙박           8697
# Name: count, dtype: int64

# %%
shop_edu = shop[shop['상권업종대분류명'] == '교육']
shop_edu
# Out:
#                  상호명  지점명 상권업종대분류명 상권업종중분류명      상권업종소분류명    시도명 시군구명  \
# 103            백장미댄스  NaN       교육    기타 교육   레크리에이션 교육기관  서울특별시  도봉구
# 143        현대라이프레이키인  NaN       교육    교육 지원  기타 교육지원 서비스업  서울특별시  종로구
# %%
plt.figure(figsize=(14, 10))
sns.scatterplot(data=shop_edu_etc_computer, x='경도', y='위도', hue='상권업종소분류명')
# Out:
# <Axes: xlabel='경도', ylabel='위도'>

# %% [markdown]
# # **3. Folium**
# [Folium](https://python-visualization.github.io/folium/latest/)은 파이썬에서 대화형 지도(interactive map)를 생성할 수 있는 라이브러리입니다. 특히, 지리 데이터(Geospatial Data) 시각화에 최적화되어 있으며, 간단한 코드로 복잡한 지도 기능을 구현할 수 있도록 도와줍니다.

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.7)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2025.7.14)

# %%
import folium

map_folium = folium.Map(location=[37.56652479270633, 126.9779129116262], zoom_start=15)
popup = folium.Popup('서울특별시청', max_width=200)
folium.Marker(location=[37.56652479270633, 126.9779129116262], popup=popup).add_to(map_folium)

popup = folium.Popup('덕수궁', max_width=200)
folium.Marker(location=[37.56585320879458, 126.97514572197248], popup=popup).add_to(map_folium)

popup = folium.Popup('서울지방경찰청', max_width=200)
folium.Marker(location=[37.57504045678939, 126.97195576938117], popup=popup).add_to(map_folium)

popup = folium.Popup('광화문', max_width=200)
folium.Marker(location=[37.57617987638928, 126.97694467807803], popup=popup).add_to(map_folium)

popup = folium.Popup('영풍문고-종로본점', max_width=200)
folium.Marker(location=[37.56999947440024, 126.98228391170936], popup=popup).add_to(map_folium)

map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be7dc20e122df84ce72b6bfaa2d9eead {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be7dc20e122df84ce72b6bfaa2d9eead&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be7dc20e122df84ce72b6bfaa2d9eead = L.map(
#                 &quot;map_be7dc20e122df84ce72b6bfaa2d9eead&quot;,
#                 {
#                     center: [37.56652479270633, 126.9779129116262],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49be26fdd88cbe0ca85b8f6190d66b87 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49be26fdd88cbe0ca85b8f6190d66b87.addTo(map_be7dc20e122df84ce72b6bfaa2d9eead);
#
#
#             var marker_0bedea3ae8773c23acb2505455a62b81 = L.marker(
#                 [37.56652479270633, 126.9779129116262],
#                 {
# }
#             ).addTo(map_be7dc20e122df84ce72b6bfaa2d9eead);
#
#
#         var popup_dd00efbcc5c165b561169d3c58ea3851 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_77de3eb11bc1c2df98d8c2db9ea0e21f = $(`&lt;div id=&quot;html_77de3eb11bc1c2df98d8c2db9ea0e21f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_dd00efbcc5c165b561169d3c58ea3851.setContent(html_77de3eb11bc1c2df98d8c2db9ea0e21f);
#
#
#
#         marker_0bedea3ae8773c23acb2505455a62b81.bindPopup(popup_dd00efbcc5c165b561169d3c58ea3851)
#         ;
#
#
#
#
#             var marker_9dd354831c68457d9b1d3376350342ad = L.marker(
#                 [37.56585320879458, 126.97514572197248],
#                 {
# }
#             ).addTo(map_be7dc20e122df84ce72b6bfaa2d9eead);
#
#
#         var popup_77629b4418c3b44d7e3b47a6718ddc79 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_cd759d356dfb18d2e95854fc894551a1 = $(`&lt;div id=&quot;html_cd759d356dfb18d2e95854fc894551a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁&lt;/div&gt;`)[0];
#                 popup_77629b4418c3b44d7e3b47a6718ddc79.setContent(html_cd759d356dfb18d2e95854fc894551a1);
#
#
#
#         marker_9dd354831c68457d9b1d3376350342ad.bindPopup(popup_77629b4418c3b44d7e3b47a6718ddc79)
#         ;
#
#
#
#
#             var marker_3be508e296bd0c444d82afa7d20bdd39 = L.marker(
#                 [37.57504045678939, 126.97195576938117],
#                 {
# }
#             ).addTo(map_be7dc20e122df84ce72b6bfaa2d9eead);
#
#
#         var popup_7d7b5167175180ceaa1aac587b8f9b9a = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_d34c474817037d3575095002fbd54552 = $(`&lt;div id=&quot;html_d34c474817037d3575095002fbd54552&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울지방경찰청&lt;/div&gt;`)[0];
#                 popup_7d7b5167175180ceaa1aac587b8f9b9a.setContent(html_d34c474817037d3575095002fbd54552);
#
#
#
#         marker_3be508e296bd0c444d82afa7d20bdd39.bindPopup(popup_7d7b5167175180ceaa1aac587b8f9b9a)
#         ;
#
#
#
#
#             var marker_b7ffa1952314bbe52b384a3f6a7b462c = L.marker(
#                 [37.57617987638928, 126.97694467807803],
#                 {
# }
#             ).addTo(map_be7dc20e122df84ce72b6bfaa2d9eead);
#
#
#         var popup_69a1d7082f9e4fc978f9f75acb82ee8d = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_6fa5a3083323c14b92e0f114c845dc56 = $(`&lt;div id=&quot;html_6fa5a3083323c14b92e0f114c845dc56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광화문&lt;/div&gt;`)[0];
#                 popup_69a1d7082f9e4fc978f9f75acb82ee8d.setContent(html_6fa5a3083323c14b92e0f114c845dc56);
#
#
#
#         marker_b7ffa1952314bbe52b384a3f6a7b462c.bindPopup(popup_69a1d7082f9e4fc978f9f75acb82ee8d)
#         ;
#
#
#
#
#             var marker_f52ef6f21feb7fc5cb8ba8ecf49ba8ba = L.marker(
#                 [37.56999947440024, 126.98228391170936],
#                 {
# }
#             ).addTo(map_be7dc20e122df84ce72b6bfaa2d9eead);
#
#
#         var popup_04751a34a0eee136d1d4771f0c14c8a7 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_252f657a89e59486e26fba801a1343a1 = $(`&lt;div id=&quot;html_252f657a89e59486e26fba801a1343a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;영풍문고-종로본점&lt;/div&gt;`)[0];
#                 popup_04751a34a0eee136d1d4771f0c14c8a7.setContent(html_252f657a89e59486e26fba801a1343a1);
#
#
#
#         marker_f52

# %%
from folium.features import CustomIcon

icon = CustomIcon('images.png', icon_size=(45, 45))

map_folium = folium.Map(location=[37.56652479270633, 126.9779129116262], zoom_start=15)
popup = folium.Popup('서울특별시청', max_width=200)
folium.Marker(location=[37.56652479270633, 126.9779129116262], popup=popup,
              icon=folium.Icon(icon='star', color='red')).add_to(map_folium)

popup = folium.Popup('덕수궁', max_width=200)
folium.Marker(location=[37.56585320879458, 126.97514572197248], popup=popup,
              icon=folium.Icon(icon='ok', color='pink')).add_to(map_folium)

popup = folium.Popup('서울지방경찰청', max_width=200)
folium.Marker(location=[37.57504045678939, 126.97195576938117], popup=popup,
              icon=icon).add_to(map_folium)

popup = folium.Popup('광화문', max_width=200)
folium.Marker(location=[37.57617987638928, 126.97694467807803], popup=popup).add_to(map_folium)

# CircleMarker(): 원의 범위를 마커로 설정
popup = folium.Popup('내땅', max_width=200)
folium.CircleMarker(location=[37.56999947440024, 126.98228391170936], popup=popup,
              radius=30, color='red', fill_color='#ec4074').add_to(map_folium)

map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2843b089b0f39045bae41e09b696922 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2843b089b0f39045bae41e09b696922&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2843b089b0f39045bae41e09b696922 = L.map(
#                 &quot;map_a2843b089b0f39045bae41e09b696922&quot;,
#                 {
#                     center: [37.56652479270633, 126.9779129116262],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec13e592959aa5350d65aa7b99632d63 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec13e592959aa5350d65aa7b99632d63.addTo(map_a2843b089b0f39045bae41e09b696922);
#
#
#             var marker_5ef5e2bc9539fb96ec9e574d5b33ab0c = L.marker(
#                 [37.56652479270633, 126.9779129116262],
#                 {
# }
#             ).addTo(map_a2843b089b0f39045bae41e09b696922);
#
#
#             var icon_d2ab3679d5a4d6e04a26970d258d714a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_bef0a53dce3dfc77757d8bf1e8d04323 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_787261e916753b228276188c429eb060 = $(`&lt;div id=&quot;html_787261e916753b228276188c429eb060&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_bef0a53dce3dfc77757d8bf1e8d04323.setContent(html_787261e916753b228276188c429eb060);
#
#
#
#         marker_5ef5e2bc9539fb96ec9e574d5b33ab0c.bindPopup(popup_bef0a53dce3dfc77757d8bf1e8d04323)
#         ;
#
#
#
#
#                 marker_5ef5e2bc9539fb96ec9e574d5b33ab0c.setIcon(icon_d2ab3679d5a4d6e04a26970d258d714a);
#
#
#             var marker_a156f30bff73907d44a6ecd9743b0f7a = L.marker(
#                 [37.56585320879458, 126.97514572197248],
#                 {
# }
#             ).addTo(map_a2843b089b0f39045bae41e09b696922);
#
#
#             var icon_7adf0f49e8e46e1abe0bc8339687cf32 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;pink&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e72eda6320ce661d320be610d14431e7 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_0fcd24667b7f31848ca1eb696e081618 = $(`&lt;div id=&quot;html_0fcd24667b7f31848ca1eb696e081618&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁&lt;/div&gt;`)[0];
#                 popup_e72eda6320ce661d320be610d14431e7.setContent(html_0fcd24667b7f31848ca1eb696e081618);
#
#
#
#         marker_a156f30bff73907d44a6ecd9743b0f7a.bindPopup(popup_e72eda6320ce661d320be610d14431e7)
#         ;
#
#
#
#
#                 marker_a156f30bff73907d44a6ecd9743b0f7a.setIcon(icon_7adf0f49e8e46e1abe0bc8339687cf32);
#
#
#             var marker_97a88e6daf427969c0655a0c5c332dc2 = L.marker(
#                 [37.57504045678939, 126.97195576938117],
#                 {
# }
#             ).addTo(map_a2843b089b0f39045bae41e09b696922);
#
#
#         var icon_926944fca95681f7d0247b4695b34f42 = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [45, 45],
# });
#
#
#         var popup_c0e89597fc409f282433a49d715e3260 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_b39a1aed8d08a3c3c9ac83fe5688e8b1 = $(`&lt;div id=&quot;html_b39a1aed8d08a3c3c9ac83fe5688e8b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울지방경찰청&lt;/div&gt;`)[0];
#                 popup_c0e89597fc409f282433a49d715e3260.setContent(html_b39a1aed8d08a3c3c9ac83fe5688e8b1);
#
#
#
#         marker_97a88e6daf427969c0655a0c5c332dc2.bindPopup(popup_c0e89597fc409f282433a49d715e3260)
#         ;
#
#
#
#
#                 marker_97a88e6daf427969c0655a0c5c332dc2.setIcon(icon_926944fca95681f7d0247b4695b34f42);
#
#
#             var marker_b34bdbebb3410430a72f1350c6c7bb14 = L.marker(
#                 [37.57617987638928, 126.97694467807803],
#                 {
# }
#             ).addTo(map_a2843b089b0f39045bae41e09b696922);
#
#
#         var popup_

# %%
data = shop_edu_etc_computer

edu_map = folium.Map(location=[data['위도'].mean(), data['경도'].mean()], zoom_start=12)

for i in data.index:
    edu_name = data.loc[i, '상호명'] + ' - ' + data.loc[i, '도로명주소']
    # print(edu_name)
    popup = folium.Popup(edu_name, max_width=500)
    folium.Marker(location=[data.loc[i, '위도'], data.loc[i, '경도']],
                  popup=popup).add_to(edu_map)

edu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c251588320d3f67f4a2d66c89112622d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c251588320d3f67f4a2d66c89112622d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c251588320d3f67f4a2d66c89112622d = L.map(
#                 &quot;map_c251588320d3f67f4a2d66c89112622d&quot;,
#                 {
#                     center: [37.533283823901556, 126.99043741725902],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b05b7eec09c5846d9509c23fde405723 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b05b7eec09c5846d9509c23fde405723.addTo(map_c251588320d3f67f4a2d66c89112622d);
#
#
#             var marker_34c195582e750546169374dd5dd1ddcd = L.marker(
#                 [37.5476963140273, 126.917708863218],
#                 {
# }
#             ).addTo(map_c251588320d3f67f4a2d66c89112622d);
#
#
#         var popup_02ff483a4ed267a7fec5b424901a2829 = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var html_84defb592518df52d79d53997fa207b4 = $(`&lt;div id=&quot;html_84defb592518df52d79d53997fa207b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;창조E&amp;P - 서울특별시 마포구 독막로6길 5&lt;/div&gt;`)[0];
#                 popup_02ff483a4ed267a7fec5b424901a2829.setContent(html_84defb592518df52d79d53997fa207b4);
#
#
#
#         marker_34c195582e750546169374dd5dd1ddcd.bindPopup(popup_02ff483a4ed267a7fec5b424901a2829)
#         ;
#
#
#
#
#             var marker_4313f97b3adc42555d51902f2d830576 = L.marker(
#                 [37.5697088977199, 126.990027526307],
#                 {
# }
#             ).addTo(map_c251588320d3f67f4a2d66c89112622d);
#
#
#         var popup_1fbdfd8b12c4aa58b64502c3b2dd88b5 = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var html_f9fb3c8fa1df54d76fe6a25f34e7e5da = $(`&lt;div id=&quot;html_f9fb3c8fa1df54d76fe6a25f34e7e5da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;지아이티아카데미종로주 - 서울특별시 종로구 수표로 96&lt;/div&gt;`)[0];
#                 popup_1fbdfd8b12c4aa58b64502c3b2dd88b5.setContent(html_f9fb3c8fa1df54d76fe6a25f34e7e5da);
#
#
#
#         marker_4313f97b3adc42555d51902f2d830576.bindPopup(popup_1fbdfd8b12c4aa58b64502c3b2dd88b5)
#         ;
#
#
#
#
#             var marker_7dafc67346e73635f38b81e423b426b5 = L.marker(
#                 [37.5381067622606, 127.126385335571],
#                 {
# }
#             ).addTo(map_c251588320d3f67f4a2d66c89112622d);
#
#
#         var popup_c8dae4749f54bbe715019ec3b736a82a = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var html_2f35d408b08753172d03643d75056ac0 = $(`&lt;div id=&quot;html_2f35d408b08753172d03643d75056ac0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;하이미디어컴퓨터학원 - 서울특별시 강동구 천호대로 1027&lt;/div&gt;`)[0];
#                 popup_c8dae4749f54bbe715019ec3b736a82a.setContent(html_2f35d408b08753172d03643d75056ac0);
#
#
#
#         marker_7dafc67346e73635f38b81e423b426b5.bindPopup(popup_c8dae4749f54bbe715019ec3b736a82a)
#         ;
#
#
#
#
#             var marker_0d4adc14f14915fa31c5e1f91a1e2882 = L.marker(
#                 [37.5721687746264, 127.0078559868],
#                 {
# }
#             ).addTo(map_c251588320d3f67f4a2d66c89112622d);
#
#
#         var popup_c31b209b7162b7e95ac3fc604dbca973 = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var html_23b0ee9a26d02d2f05bdce75135ea4d6 = $(`&lt;div id=&quot;html_23b0ee9a26d02d2f05bdce75135ea4d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울게임 - 서울특별시 종로구 율곡로 282&lt;/div&gt;`)[0];
#                 popup_c31b209b7162b7e95ac3fc604dbca973.setContent(html_23b0ee9a26d02d2f05bdce75135ea4d6);
#
#
#
#         marker_0d4adc14f14915fa31c5e1f91a1e2882.bindPopup(popup_c31b209b7162b7e95ac3fc604dbca973)
#         ;
#
#
#
#
#             var marker_be7631a1d731c6e5b5e2be9561e35b0b = L.marker(
#                 [37.5729616569779, 126.992245809785],
#                 {
# }
#             ).addTo(map_c251588320d3f67f4a2d66c89112622d);
#
#
#         var popup_b06a08cd5fbaf6213c583a74a0d223e6 = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var html_04223a6bf3aa9e445b43bbc6823cca2e = $(`&lt;div id=&quot;html_04223a6bf3aa9e445b43bbc6823cca2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;중앙에이치티에이 - 서울특별시 종로구 율곡로10길 105&lt;/div&gt;`)[0];
#                 popup_b06a08cd5fbaf6213c583
